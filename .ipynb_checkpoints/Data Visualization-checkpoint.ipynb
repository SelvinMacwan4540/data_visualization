# %% [markdown]
# # Univariate Plots

# %%
import pandas as pd

import matplotlib.pyplot as plt
data = pd.read_csv("breast_cancer_data.csv")
plt.hist(data)
plt.show()

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'mean_radius'}>,
#         <AxesSubplot:title={'center':'mean_texture'}>],
#        [<AxesSubplot:title={'center':'mean_perimeter'}>,
#         <AxesSubplot:title={'center':'mean_area'}>],
#        [<AxesSubplot:title={'center':'mean_smoothness'}>,
#         <AxesSubplot:title={'center':'diagnosis'}>]], dtype=object)

# %%
data.plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.plot(kind = 'density', subplots = True, layout = (3,3), sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
data.plot(kind = 'box', subplots = True, layout= (3,3), sharex = False, sharey = False )
# Out:
# mean_radius           AxesSubplot(0.125,0.657941;0.227941x0.222059)
# mean_texture       AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# mean_perimeter     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# mean_area             AxesSubplot(0.125,0.391471;0.227941x0.222059)
# mean_smoothness    AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# diagnosis          AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# dtype: object

# %%
data.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Multivariate Plots

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8ac81bb7df59> in <module>
# ----> 1 from pandas.tools.plotting import scatter_matrix
#       2 scatter_matrix(data)
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection="3d")

# %%
import matplotlib.pyplot as plt
exp = [0,0,0.2,0,0,0.5,0,0.1]
lab = [1,2,3,4,5,6,7,8]
values = [1,6,8,4,1,5,4,9]



plt.pie(values, explode = exp, labels = lab)# distance from center is called explode
# Out:
# ([<matplotlib.patches.Wedge at 0x1a628189ec8>,
#   <matplotlib.patches.Wedge at 0x1a628196d48>,
#   <matplotlib.patches.Wedge at 0x1a6281988c8>,
#   <matplotlib.patches.Wedge at 0x1a62819f448>,
#   <matplotlib.patches.Wedge at 0x1a62819ffc8>,
#   <matplotlib.patches.Wedge at 0x1a6281a6c48>,
#   <matplotlib.patches.Wedge at 0x1a6281ad7c8>,
#   <matplotlib.patches.Wedge at 0x1a6281b4348>],
#  [Text(1.0962429422513844, 0.09083728069481341, '1'),
#   Text(0.8680545728210498, 0.6756339679178844, '2'),
#   Text(-0.3191310913654163, 1.2602203563361125, '3'),
#   Text(-1.0403989566305283, 0.35716944304084647, '4'),
#   Text(-1.096242944377584, -0.09083725503539536, '5'),
#   Text(-1.339466371688549, -0.8751170430951017, '6'),
#   Text(-0.27003402534561777, -1.06634029519457, '7'),
#   Text(0.8828687168374458, -0.8127378598476891, '8')])
